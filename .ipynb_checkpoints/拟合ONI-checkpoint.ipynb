# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MultipleLocator
import matplotlib.dates as mdates

# %%
oni = pd.read_excel("ONI.xlsx",header=None)[:]#读取
oni_pd = oni
oni = oni.to_numpy().flatten()
oni.shape
# Out:
# (73,)

# %%
gmst = pd.read_csv("avarangeof6.csv",header=0,index_col=0)
gmst = gmst["1950":"2023"]
oni_pd.index = gmst.index
gmst = gmst['0'].to_numpy().flatten()
gmst.shape
# Out:
# (73,)

# %% [markdown]
# ## 拟合 $ y = ax+b $

# %%
coff_x = np.polyfit(oni,gmst,1)

# %%
gmst_hat = np.poly1d(coff_x)
gmst_pre = gmst_hat(oni_pd)
gmst_pre = gmst_pre.flatten()
gmst_pre.shape
# Out:
# (73,)

# %%
plt.rcParams['font.sans-serif'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False
fig,ax = plt.subplots(1,1,figsize=(12
                    ,6))
ax.plot(oni_pd.index,gmst*10, "--",lw = 2.0,label = 'gmst')
ax.plot(oni_pd.index,oni_pd, "--",lw = 2.0,label = 'ONI')
ax.plot(oni_pd.index,gmst_pre,'r--',lw = 2.0,label = 'gmst_hat')
res= gmst-gmst_pre
ax.plot(oni_pd.index,res,'-',lw = 2.0,label = 'res')
ax.legend(loc = "best")
ax.tick_params(axis='both', which='major', labelsize=12)
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.tick_params(axis='x', rotation=45)
ax.set_title("拟合")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 相关系数

# %%
y_cor= np.corrcoef(oni,res)

# %%
y_cor
# Out:
# array([[ 1.00000000e+00, -1.02195729e-16],
#        [-1.02195729e-16,  1.00000000e+00]])

# %% [markdown]
# ## 计算 $\hat{y}-y$

# %%
res = gmst - gmst_hat(oni)

# %%
plt.rcParams['font.sans-serif'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12
                    ,6))
plt.scatter(oni,res, marker="o",s = 20,edgecolors="b",label = 'gmst')
plt.legend("best")
plt.title("res")
plt.show()
